# %% [markdown]
# <h1 align= 'center'><b>INX Future Inc Employee Performance</h1></b>

# %% [markdown]
# #### **BUSINESS CASE**

# %% [markdown]
# INX Future Inc , (referred as INX ) , is one of the leading data analytics and automation solutions provider
# with over 15 years of global business presence. INX is consistently rated as top 20 best employers past 5
# years. INX human resource policies are considered as employee friendly and widely perceived as best
# practices in the industry.
#
# Recent years, the employee performance indexes are not healthy and this is becoming a growing
# concerns among the top management. There has been increased escalations on service delivery and
# client satisfaction levels came down by 8 percentage points.
#
# CEO, Mr. Brain, knows the issues but concerned to take any actions in penalizing non-performing
# employees as this would affect the employee morale of all the employees in general and may further
# reduce the performance. Also, the market perception best employer and thereby attracting best talents
# to join the company.
#
# Mr. Brain decided to initiate a data science project , which analyses the current employee data and find
# the core underlying causes of this performance issues. Mr. Brain, being a data scientist himself, expects
# the findings of this project will help him to take right course of actions. He also expects a clear indicators
# of non performing employees, so that any penalization  of non-performing employee, if required, may
# not significantly affect other employee morals.

# %% [markdown]
# #### **PROBLEM STATEMENT**

# %% [markdown]
# - To develop a data science project to identify the **root causes of declining employee performance indexes** at INX Future Inc. and provide clear indicators for non-performing employees without negatively impacting overall employee morale or the company's reputation as a top employer.
#
# - **Identifying patterns of attrition** within the employee data could be essential in understanding the underlying causes of the performance issues and developing strategies to mitigate them.

# %% [markdown]
# #### **IMPORTING THE LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### **IMPORTING THE DATASET**

# %%
# !pip install xlrd>=2.0.1

# %%
data= pd.read_excel(r"E:\Employee_Performance_Analysis\INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls")
data
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %% [markdown]
# #### **DOMAIN ANALYSIS**

# %% [markdown]
# 1. ***EmpNumber:*** Unique identifier for each employee in the dataset.
#
# 2. ***Age:*** Age of the employee, providing insight into workforce demographics and potential correlations with attrition.
#
# 3. ***Gender:*** Gender of the employee, which may impact workplace dynamics and attrition patterns.
#
# 4. ***EducationBackground:*** The educational background of the employee, influencing skillset and career trajectory.
#
# 5. ***MaritalStatus:*** Marital status of the employee, potentially affecting work-life balance and job satisfaction.
#
# 6. ***EmpDepartment:*** Department in which the employee works, indicating job role and organizational structure.
#
# 7. ***EmpJobRole:*** Specific job role of the employee within their department, reflecting responsibilities and career path.
#
# 8. ***BusinessTravelFrequency:*** Frequency of business travel for the employee, impacting lifestyle and job satisfaction.
#
# 9. ***DistanceFromHome:*** Distance of employee's residence from the workplace, influencing commuting stress and retention.
#
# 10. ***EmpEducationLevel:*** Level of education attained by the employee, reflecting qualifications and potential for advancement.
#
# 11. ***EmpEnvironmentSatisfaction:*** Employee satisfaction with the work environment, affecting morale and turnover.
#
# 12. ***EmpHourlyRate:*** Hourly wage of the employee, a factor in compensation satisfaction and retention.
#
# 13. ***EmpJobInvolvement:*** Level of involvement and engagement in the job role, affecting performance and attrition risk.
#
# 14. ***EmpJobLevel:*** Level of hierarchy within the organization, indicating seniority and career progression.
#
# 15. ***EmpJobSatisfaction:*** Satisfaction level with the job role, impacting employee morale and retention.
#
# 16. ***NumCompaniesWorked:*** Number of companies the employee has previously worked for, indicating job stability and turnover risk.
#
# 17. ***OverTime:*** Whether the employee works overtime, influencing work-life balance and burnout.
#
# 18. ***EmpLastSalaryHikePercent:*** Percentage of the employee's last salary hike, affecting compensation satisfaction and retention.
#
# 19. ***EmpRelationshipSatisfaction:*** Satisfaction with relationships at work, influencing job satisfaction and likelihood of turnover.
#
# 20. ***TotalWorkExperienceInYears:*** Total work experience of the employee, influencing skill level and career trajectory.
#
# 21. ***TrainingTimesLastYear:*** Number of training sessions attended by the employee last year, indicating investment in skill development and career growth.
#
# 22. ***EmpWorkLifeBalance:*** Employee's perceived balance between work and personal life, affecting job satisfaction and retention.
#
# 23. ***ExperienceYearsAtThisCompany:*** Years of experience at the current company, indicating loyalty and potential for promotion.
#
# 24. ***ExperienceYearsInCurrentRole:*** Years of experience in the current job role, influencing expertise and potential for advancement.
#
# 25. ***YearsSinceLastPromotion:*** Time since the employee's last promotion, impacting career progression and job satisfaction.
#
# 26. ***YearsWithCurrManager:*** Years of tenure with the current manager, affecting job satisfaction and retention.
#
# 27. ***Attrition:*** Target variable indicating whether the employee has left the company, essential for attrition prediction modeling.
#
# 28. ***PerformanceRating:*** Performance rating assigned to the employee, influencing career development and potential for retention.

# %% [markdown]
# #### **BASIC CHECKS**

# %%
data.shape
# Out:
# (1200, 28)

# %%
# last five rows
data.tail()
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 1195   E100992   27  Female             Medical      Divorced         Sales
# 1196   E100993   37    Male       Life Sciences        Single   Development
# 1197   E100994   50    Male             Medical       Married   Development
# 1198   E100995   34  Female             Medical        Single  Data Science
# 1199   E100998   24  Female       Life Sciences        Single         Sales
#
#             EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 1195   Sales Executive       Travel_Frequently                 3
# 1196  Senior Developer           Travel_Rarely                10
# 1197  Senior Developer           Travel_Rarely                28
# 1198    Data Scientist           Travel_Rarely                 9
# 1199   Sales Executive           Travel_Rarely                 3
#
#       EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# ...

# %%
# columns
data.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %% [markdown]
# ##### Insights:
# - There are 19 features with int64 datatype and the rest of the 9 fetures are of object datatype.
# - There are no null values in the records.

# %%
# viewing the statistical information
data.describe().T.style.background_gradient(cmap= 'cool')
# Out:
# <style type="text/css">
# #T_c4cbe_row0_col0, #T_c4cbe_row1_col0, #T_c4cbe_row2_col0, #T_c4cbe_row3_col0, #T_c4cbe_row3_col7, #T_c4cbe_row4_col0, #T_c4cbe_row5_col0, #T_c4cbe_row5_col6, #T_c4cbe_row5_col7, #T_c4cbe_row6_col0, #T_c4cbe_row6_col1, #T_c4cbe_row6_col6, #T_c4cbe_row7_col0, #T_c4cbe_row7_col7, #T_c4cbe_row8_col0, #T_c4cbe_row8_col3, #T_c4cbe_row9_col0, #T_c4cbe_row10_col0, #T_c4cbe_row10_col7, #T_c4cbe_row11_col0, #T_c4cbe_row11_col3, #T_c4cbe_row12_col0, #T_c4cbe_row12_col3, #T_c4cbe_row12_col6, #T_c4cbe_row13_col0, #T_c4cbe_row13_col6, #T_c4cbe_row13_col7, #T_c4cbe_row14_col0, #T_c4cbe_row14_col3, #T_c4cbe_row15_col0, #T_c4cbe_row15_col3, #T_c4cbe_row16_col0, #T_c4cbe_row16_col1, #T_c4cbe_row16_col3, #T_c4cbe_row16_col4, #T_c4cbe_row16_col5, #T_c4cbe_row16_col6, #T_c4cbe_row17_col0, #T_c4cbe_row17_col3, #T_c4cbe_row18_col0, #T_c4cbe_row18_col2, #T_c4cbe_row18_col6, #T_c4cbe_row18_col7 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_c4cbe_row0_col1 {
# ...

# %% [markdown]
# The table provides statistical summaries for various employee attributes. Here's a concise analysis of each:
#
# 1. **Age:**
#    - The average age of employees is approximately 36.92 years, with a standard deviation of about 9.09 years. The age distribution is fairly spread out, ***ranging from 18 to 60 years.***
#
# 2. **DistanceFromHome:**
#    - On average, employees live around 9.17 miles away from their workplace, with a standard deviation of about 8.18 miles. The ***distance varies widely, from 1 to 29 miles***.
#
# 3. **EmpEducationLevel:**
#    - The average education level is about 2.89, with a standard deviation of approximately 1.04. The majority of employees have an education level between 1 and 5.
#
# 4. **EmpEnvironmentSatisfaction:**
#    - The average satisfaction level is around 2.72, with a standard deviation of about 1.09. The majority of employees rate their environment satisfaction between 1 and 4.
#
# 5. **EmpHourlyRate:**
#    - The average hourly rate is approximately $65.98, with a standard deviation of about $20.21. Hourly rates ***range from $30 to $100.***
#
# 6. **EmpJobInvolvement:**
#    - On average, employees show a job involvement level of about 2.73, with a standard deviation of approximately 0.71. Most employees rate their job involvement between 1 and 4.
#
# 7. **EmpJobLevel:**
#    - The average job level is around 2.07, with a standard deviation of about 1.11. Job levels range from 1 to 5, indicating a diverse workforce.
#
# 8. **EmpJobSatisfaction:**
#    - The average job satisfaction level is about 2.73, with a standard deviation of around 1.10. The majority of employees rate their job satisfaction between 1 and 4.
#
# 9. **NumCompaniesWorked:**
#    - On average, employees have worked for around 2.67 companies, with a standard deviation of approximately 2.47. ***The number of companies worked for ranges from 0 to 9.***
#
# 10. **EmpLastSalaryHikePercent:**
#     - The average salary hike percentage is approximately 15.22%, with a standard deviation of about 3.63%. ***Salary hike percentages vary from 11% to 25%.***
#
# 11. **EmpRelationshipSatisfaction:**
#     - On average, employees report a relationship satisfaction level of about 2.72, with a standard deviation of around 1.08. The majority of employees rate their relationship satisfaction between 1 and 4.
#
# 12. **TotalWorkExperienceInYears:**
#     - The average total work experience is approximately 11.33 years, with a standard deviation of about 7.80 years. ***Total work experience ranges from 0 to 40 years, indicating a diverse workforce in terms of experience.***
#
# 13. **TrainingTimesLastYear:**
#     -  On average, employees underwent training around 2.79 times last year, with a standard deviation of approximately 1.26 times. The number of training sessions varies from 0 to 6.
#
# 14. **EmpWorkLifeBalance:**
#     - The average work-life balance rating is about 2.74, with a standard deviation of around 0.70. Most employees rate their work-life balance between 1 and 4.
#
# 15. **ExperienceYearsAtThisCompany:**
#     - Employees have, on average, spent around 7.08 years at the current company, with a standard deviation of about 6.24 years. Experience years range from 0 to 40 years, indicating a diverse range of tenures.
#
# These information can be helpful in arriving a comprehensive understanding of the demographic and professional characteristics of the workforce, which can inform HR policies and management decisions.

# %%
data.describe(include= 'O').T
# Out:
#                         count unique              top  freq
# EmpNumber                1200   1200         E1001000     1
# Gender                   1200      2             Male   725
# EducationBackground      1200      6    Life Sciences   492
# MaritalStatus            1200      3          Married   548
# EmpDepartment            1200      6            Sales   373
# EmpJobRole               1200     19  Sales Executive   270
# BusinessTravelFrequency  1200      3    Travel_Rarely   846
# OverTime                 1200      2               No   847
# Attrition                1200      2               No  1022

# %% [markdown]
# ##### Insights:
# 1. **Employee Number**:
#    - All employees have a ***unique identification number.***
#    - Each employee number appears only once in the dataset.
#
# 2. **Gender**:
#    - Majority of the employees are male (725 out of 1200).
#    - There is a ***gender imbalance*** in the workforce.
#
# 3. **Education Background**:
#    - The most common educational background is in ***Life Sciences*** (492 employees).
#    - Diverse educational backgrounds are represented.
#
# 4. **Marital Status**:
#    - The majority of employees are ***married (548 out of 1200).***
#    - Single and other marital statuses are less common.
#
# 5. **Employee Department**:
#    - ***Sales is the largest department,*** with 373 employees.
#    - The workforce is distributed across multiple departments.
#
# 6. **Employee Job Role**:
#    - Sales Executive is the most common job role (270 employees).
#    - A variety of job roles are present within the organization.
#
# 7. **Business Travel Frequency**:
#    - Travel Rarely is the most common business travel frequency (846 employees).
#    - Some employees may travel more frequently for work.
#
# 8. **Overtime**:
#    - The ***majority of employees do not work overtime*** (847 out of 1200).
#    - Work-life balance might be prioritized in this organization.
#
# 9. **Attrition**:
#    - The majority of employees have not left the company (1022 out of 1200).
#    - ***Attrition rate*** appears to be relatively low.

# %%
data.nunique().to_frame().T.style.background_gradient(cmap= 'cool')
# Out:
# <style type="text/css">
# #T_7125b_row0_col0, #T_7125b_row0_col1, #T_7125b_row0_col2, #T_7125b_row0_col3, #T_7125b_row0_col4, #T_7125b_row0_col5, #T_7125b_row0_col6, #T_7125b_row0_col7, #T_7125b_row0_col8, #T_7125b_row0_col9, #T_7125b_row0_col10, #T_7125b_row0_col11, #T_7125b_row0_col12, #T_7125b_row0_col13, #T_7125b_row0_col14, #T_7125b_row0_col15, #T_7125b_row0_col16, #T_7125b_row0_col17, #T_7125b_row0_col18, #T_7125b_row0_col19, #T_7125b_row0_col20, #T_7125b_row0_col21, #T_7125b_row0_col22, #T_7125b_row0_col23, #T_7125b_row0_col24, #T_7125b_row0_col25, #T_7125b_row0_col26, #T_7125b_row0_col27 {
#   background-color: #00ffff;
#   color: #000000;
# }
# </style>
# <table id="T_7125b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7125b_level0_col0" class="col_heading level0 col0" >EmpNumber</th>
#       <th id="T_7125b_level0_col1" class="col_heading level0 col1" >Age</th>
# ...

# %% [markdown]
# ##### Insights:
# - **Numerical features**:
#   -  **continuous_features:** 'EmpNumber', 'Age', 'DistanceFromHome', EmpHourlyRate', 'TotalWorkExperienceInYears', 'ExperienceYearsAtThiscompany'.
#   -  **discrete_features:**  'EmpEducationLevel', 'EmpEnvironmentSatisfaction', 'EmpJobInvolvement', 'EmpJobLevel', 'EmpJobSatisfaction', 'NumCompaniesWorked', 'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction', 'TrainingTimesLastYear', 'EmpWorkLifeBalance', 'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'PerformanceRating'.
#
# - **Categorical features**:
#   -  **binary_features** 'OverTime', 'Attrition'.
#   -  **nominal_fetures:** 'Gender', 'EducationBackground', 'MaritalStatus', 'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency'.

# %% [markdown]
# #### **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# #### **UNIVARIATE ANALYSIS**

# %% [markdown]
# #### **Distribution of independent features**

# %%
target = 'Attrition'
independent_features= [column for column in data.drop(target, axis=1)]

# let's take a threshold of less than 20 unique values for a feature to be
# considered as a categorical feature
categorical_features= [column for column in independent_features if data[column].nunique() < 20]
continuous_features= [column for column in independent_features if data[column].nunique() >=20]

print(f'Target variable: {target}\nTotal no of independent features (except target): {len(independent_features)}')
print(f'No of categorical features (<20 distinct values): {len(categorical_features)}')
print(f'No of continuous features: {len(continuous_features)}')
# Out:
# Target variable: Attrition
# Total no of independent features (except target): 27
# No of categorical features (<20 distinct values): 21
# No of continuous features: 6

# %%
# pie chart showing the distribution
plt.pie([len(categorical_features), len(continuous_features)],
        labels= ['categorical features(<20 distinct values)', 'continuous features'],
        colors= ['palegreen','lightskyblue'],
        textprops= {'fontsize': 10},
        wedgeprops= {'edgecolor': 'white'},
        autopct= '%.1f%%')

plt.title('DISTRIBUTION OF CATEGORICAL AND CONTINUOUS FEATURES', fontsize= 13)
plt.show()

# %% [markdown]
# #### Target variable

# %%
value_counts= data['Attrition'].value_counts(normalize= True)
value_counts

# No- the employee has not left the company
# Yes- the employee has left the company
# Out:
# Attrition
# No     0.851667
# Yes    0.148333
# Name: proportion, dtype: float64

# %%
# visualizing each class of the target variable and their proportions

plt.figure(figsize=(8,5))
ax=sns.countplot(data= data, x= "Attrition", palette= 'cool')

# iterating over each bar of the countplot created
for i in ax.patches:

    # get_x pulls the text left or right; 
    # get_height pushes the text up or down
    ax.text(i.get_x() + 0.2, i.get_height() +0.5,\
            str(round(i.get_height(), 2)), fontsize=15)
plt.title("Attrition")
plt.show()

# %% [markdown]
# #### Insights:
# - **"No"** represents the highest portion of the records of around **85%**.
# - **"Yes"** represents the lower portion of the records of around **14%**.
# - Hence the dataset shows **imbalanced representation** interms of the target variable.

# %% [markdown]
# #### **Categorical features**

# %%
len(categorical_features)
# Out:
# 21

# %%
discrete_features= ['EmpEducationLevel', 'EmpEnvironmentSatisfaction', 'EmpJobInvolvement', 'EmpJobLevel', 'EmpJobSatisfaction', 'NumCompaniesWorked', 'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction', 'TrainingTimesLastYear', 'EmpWorkLifeBalance', 'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'PerformanceRating']
binary_features= ['OverTime']
nominal_features= ['Gender', 'EducationBackground', 'MaritalStatus', 'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency']
categorical_columns= discrete_features + binary_features + nominal_features 
len(categorical_columns)
# Out:
# 21

# %% [markdown]
# #### **i) discrete features**

# %%
fig, axes = plt.subplots(7, 2, figsize=(15, 30))
sns.set_style('darkgrid')
plotnumber = 0

for column in discrete_features:
    if plotnumber < 15:   
        # row and column indices of the subplot are calculated 
        ax = axes[plotnumber // 2, plotnumber % 2]
        sns.countplot(data=data, x=column, palette='flare',
                      orient='v', ax=ax)
        
        # Title, x label, y label
        ax.set_title(f'"{column}"', fontsize=15, fontweight='bold')
        ax.set_xlabel(column, fontsize=10)
        ax.set_ylabel('count', fontsize=10)

        # Increasing tick label sizes
        ax.tick_params(axis='x', labelsize=10)
        ax.tick_params(axis='y', labelsize=10)
        
        # Displaying bar values in percentage rounded off to two decimal digits with '%' sign
        # calculates the total no of datapoints for % 
        total = float(len(data))

        # iterates through each patch (bar)
        for p in ax.patches:

            # get_height()--> height of the current bar
            height = p.get_height()
            # positions the text at the center of each bar 
            ax.text(p.get_x() + p.get_width() / 2., height + 5,
                    f'{height / total * 100:.1f}%', ha="center", fontsize=10, fontweight= 'bold')

    plotnumber += 1

plt.subplots_adjust(hspace=2, wspace=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insights:
# - Around 37% of employees have moderate level of education of 3 followed by education level of 4. Hence around **53% of employees possess moderate and higher education levels**.
# - The work environment satisfaction is given rating of 3 and 4 by around 30% of employees. It shows around **60% employees are well satisfied with the work environment**.
# - Around 60% of employees are well involved in their job and around **73% of employees occupy the heirarchy of level 1 and 2 seniority in the job level**.
# - Around 60% are well satisfied with their job.
# - Around **70% of employees worked for less than 4 companies before** and among them around 36% worked for only one company and 13% never worked for any company before.
# - Around **55% of employees have had salary hike of less than 15%.**
# - 70% of employees have been trained for two to three times in the last one year.
# - 60% of employees have work-life balance of level 3 which is considerably good.
# - **15% of employees are freshers** and **25% of employees have 2 years of experience** in their current role.
# - It has been one year since 25% employees are promoted and 40% of employees had been promoted in less than a year ago.
# - Around 40% of employees have been working with the current manager for less than two years.
# - around **73% of employees have the performance rating of 3** which is high in general.

# %% [markdown]
# #### **ii) binary features, nominal features**

# %%
cat_columns_1= binary_features + nominal_features
len(cat_columns_1)
# Out:
# 7

# %%
fig, axes = plt.subplots(4, 2, figsize=(15, 20))
sns.set_style('darkgrid')
plotnumber = 0

for column in cat_columns_1:
    if plotnumber <7:   
        # row and column indices of the subplot are calculated 
        ax = axes[plotnumber // 2, plotnumber % 2]
        sns.countplot(data=data, x=column, palette='flare',
                      orient='v', ax=ax)
        
        # Title, x label, y label
        ax.set_title(f'"{column}"', fontsize=15, fontweight='bold')
        ax.set_xlabel(column, fontsize=10)
        ax.set_ylabel('count', fontsize=10)

        # Increasing tick label sizes
        ax.tick_params(axis='x', labelsize=10)
        # Rotate x-axis tick labels
        ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='right', fontsize=10)
        
        # Displaying bar values in percentage rounded off to two decimal digits with '%' sign
        # calculates the total no of datapoints for % 
        total = float(len(data))

        # iterates through each patch (bar)
        for p in ax.patches:

            # get_height()--> height of the current bar
            height = p.get_height()
            # positions the text at the center of each bar 
            ax.text(p.get_x() + p.get_width() / 2., height + 5,
                    f'{height / total * 100:.1f}%', ha="center", fontsize=10, fontweight= 'bold')

    plotnumber += 1

plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insights:
# - 70% of employees have not overworked.
# - 60% of employees are male.
# - Around 40% of employees did lifesciences followed by 32% of employees hold medical degrees as educational backgroound.
# - Around 45% are married and around 32% are single, Hence around half of the employees might value work-life balance high.
# - 31% of employees are in sales department followed by around 30% of employees in development department. The least percentage occupies the data science department.
# - Around 22.5% occupy the sales executive category followed by devlopers (19.7%).
# - 70% of employees travel rarely for business trips.

# %% [markdown]
# #### **Continuous features**

# %%
continuous_columns= ['EmpNumber', 'Age', 'DistanceFromHome', 'EmpHourlyRate', 'TotalWorkExperienceInYears', 'ExperienceYearsAtThisCompany']

# %%
# Distribution plots are plotted to show the data distribution 
from matplotlib.pyplot import rcParams
rcParams['figure.figsize']= [15,15]
# sns.set_style('ticks')
data.hist(['EmpNumber', 'Age', 'DistanceFromHome', 'EmpHourlyRate', 'TotalWorkExperienceInYears', 'ExperienceYearsAtThisCompany'], color= "purple", ec= 'white')
plt.show()

# %% [markdown]
# #### Insights:
# - EmpNumber is a unique feature hence it is ignored.
# - Age shows normal distribution.
# - DistanceFromHome shows no trend however it has representation across all the categories.
# - EmpHourlyRate shows uniform distsribution.
# - TotaWorkexperienceInYears and ExperienceYearsAtThiscompany show positively skewed distribution.

# %% [markdown]
# #### **BIVARIATE ANALYSIS**

# %% [markdown]
# #### **Categorical features Vs Target variable (categorical)**

# %%
plt.figure(figsize= (30, 50))
sns.set_style('darkgrid')
plotnumber=1

for column in categorical_columns:
  if plotnumber<22:
      ax= plt.subplot(11, 2, plotnumber)
      sns.countplot(data= data, x= column, palette= 'magma', hue= 'Attrition')
      ax.set_title(f'{column} vs "Attrition"', fontsize= 15, fontweight= 'bold')
      total = float(len(data))

        # iterates through each patch (bar)
      for p in ax.patches:


          # get_height()--> height of the current bar
          height = p.get_height()
          # positions the text at the center of each bar
          ax.text(p.get_x() + p.get_width() / 2, height + 5,
                    f'{height / total * 100:.1f}%', ha="center", fontsize=15, fontweight= 'bold')
      plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insights:
# - One common insight form all the above graphs seems to be that the "No" category of Attrition dominates in all the categorical features.
# - This represents the previous insights as similar to that of univariate analysis and when comparing the categories of each feature, most of the employees in the dominating category have not left the company.
# - For instance, in the **Employees education level**, the dominating category is 3rd level. Among them, around 31% belong to "No" attrition category and remaining 5% belong to "Yes" category.
# - However, the trend is different in few features.
# - Eventhough the **employees have work environment satisfaction of 4th level, they have the high attrition rate** compared to the other categories. This goes in a similar way to that of employees job satisfaction.
# - Since **the target variable is imbalanced**, this visualization may not reveal the true trend of the data distribution.

# %% [markdown]
# #### **Continuous features Vs Target variable (categorical)**

# %%
continuous_col = ['Age', 'DistanceFromHome', 'EmpHourlyRate', 'TotalWorkExperienceInYears', 'ExperienceYearsAtThisCompany']

# %%
plt.figure(figsize= (12, 8))
sns.set_style('darkgrid')
plotnumber=1

for column in continuous_col:
  if plotnumber<=6:
      ax= plt.subplot(3, 2, plotnumber)
      sns.boxplot(data= data, x= data['Attrition'], y= column, palette= 'magma')
      ax.set_title(f'{column} vs "Attrition"', fontsize= 15, fontweight= 'bold')
      
  plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Insights:
#
# - These boxplots show the data distribution for the continuous columns for both the categories of the target variable such as follows:
#
#   - Employees with age of 30-45 years have "No" attrition rate but employees of **28-38 years are more likely to leave** the company.
#   - Employees with travel **distance of more than 12 miles** are more probable to leave the company.
#   - **Hourly rate** of employees shows **no significant correlation** with the target variable.
#   - Employees of more than 10 years have less attrition rate and less than 8 years of experience shows more attrition rate. However this feature shows more outliers which might be of concern to interpret the trend correctly.

# %% [markdown]
# ### **DATA PREPROCESSING**

# %% [markdown]
# #### **CHECKING NULL VALUES:**

# %%
data.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
# hence there are no null values

# %% [markdown]
# #### **CHECKING FOR DUPLICATE RECORDS:**

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### **CHECKING FOR OUTLIERS:**

# %%
numerical_col= data[['Age',
 'DistanceFromHome',
 'EmpHourlyRate',
 'TotalWorkExperienceInYears',
 'ExperienceYearsAtThisCompany']] # fetching only continuous columns
numerical_col
# Out:
#       Age  DistanceFromHome  EmpHourlyRate  TotalWorkExperienceInYears  \
# 0      32                10             55                          10
# 1      47                14             42                          20
# 2      40                 5             48                          20
# 3      41                10             73                          23
# 4      60                16             84                          10
# ...   ...               ...            ...                         ...
# 1195   27                 3             71                           6
# 1196   37                10             80                           4
# 1197   50                28             74                          20
# 1198   34                 9             46                           9
# 1199   24                 3             65                           4
#
#       ExperienceYearsAtThisCompany
# 0                               10
# 1                                7
# ...

# %%
# using interquartile method to find out the outliers
q1= numerical_col.quantile(0.25)
q3= numerical_col.quantile(0.75)
iqr= q3 - q1
lower_lim= q1 - 1.5*iqr
upper_lim= q3 + 1.5*iqr

outliers= (numerical_col < lower_lim)|(numerical_col > upper_lim)
total_outliers= outliers.sum()
total_outliers.to_frame().T.style.background_gradient(cmap= 'Pastel1')
# Out:
# <style type="text/css">
# #T_88225_row0_col0, #T_88225_row0_col1, #T_88225_row0_col2, #T_88225_row0_col3, #T_88225_row0_col4 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# </style>
# <table id="T_88225">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88225_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_88225_level0_col1" class="col_heading level0 col1" >DistanceFromHome</th>
#       <th id="T_88225_level0_col2" class="col_heading level0 col2" >EmpHourlyRate</th>
#       <th id="T_88225_level0_col3" class="col_heading level0 col3" >TotalWorkExperienceInYears</th>
#       <th id="T_88225_level0_col4" class="col_heading level0 col4" >ExperienceYearsAtThisCompany</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88225_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88225_row0_col0" class="data row0 col0" >0</td>
# ...

# %%
# handling outliers
# TotalWorkExperienceInYears

q1= data['TotalWorkExperienceInYears'].quantile(0.25)
q3= data['TotalWorkExperienceInYears'].quantile(0.75)
iqr= q3 - q1

lower_lim= q1 - 1.5*iqr
upper_lim= q3 + 1.5*iqr

outliers= (data['TotalWorkExperienceInYears']< lower_lim) | (data['TotalWorkExperienceInYears']> upper_lim)
outliers_percent= (outliers.sum()/ (len(data))) *100
outliers_percent
# Out:
# 4.25

# %%
# Since outliers count for the feature "TotalWorkExperienceInYears" is less than 5%, they can be handled.
data.loc[data['TotalWorkExperienceInYears']< lower_lim]
# Out:
# Empty DataFrame
# Columns: [EmpNumber, Age, Gender, EducationBackground, MaritalStatus, EmpDepartment, EmpJobRole, BusinessTravelFrequency, DistanceFromHome, EmpEducationLevel, EmpEnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, TotalWorkExperienceInYears, TrainingTimesLastYear, EmpWorkLifeBalance, ExperienceYearsAtThisCompany, ExperienceYearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []
#
# [0 rows x 28 columns]

# %%
len(data.loc[data['TotalWorkExperienceInYears'] > upper_lim])
# Out:
# 51

# %%
data.loc[data['TotalWorkExperienceInYears']> upper_lim, 'TotalWorkExperienceInYears']= np.median(data['TotalWorkExperienceInYears'])

# %%
data.loc[data['TotalWorkExperienceInYears'] > upper_lim]
# Out:
# Empty DataFrame
# Columns: [EmpNumber, Age, Gender, EducationBackground, MaritalStatus, EmpDepartment, EmpJobRole, BusinessTravelFrequency, DistanceFromHome, EmpEducationLevel, EmpEnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, TotalWorkExperienceInYears, TrainingTimesLastYear, EmpWorkLifeBalance, ExperienceYearsAtThisCompany, ExperienceYearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []
#
# [0 rows x 28 columns]

# %%
# ExperienceYearsAtThisCompany

q1= data['ExperienceYearsAtThisCompany'].quantile(0.25)
q3= data['ExperienceYearsAtThisCompany'].quantile(0.75)
iqr= q3 - q1

lower_lim= q1 - 1.5*iqr
upper_lim= q3 + 1.5*iqr

outliers= (data['ExperienceYearsAtThisCompany']< lower_lim) | (data['ExperienceYearsAtThisCompany']> upper_lim)
outliers_percent= (outliers.sum()/ (len(data))) *100
outliers_percent
# Out:
# 4.666666666666667

# %%
# Since outliers count for the feature "ExperienceYearsAtThisCompany" is less than 5%, they can be handled.
data.loc[data['ExperienceYearsAtThisCompany']< lower_lim]
# Out:
# Empty DataFrame
# Columns: [EmpNumber, Age, Gender, EducationBackground, MaritalStatus, EmpDepartment, EmpJobRole, BusinessTravelFrequency, DistanceFromHome, EmpEducationLevel, EmpEnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, TotalWorkExperienceInYears, TrainingTimesLastYear, EmpWorkLifeBalance, ExperienceYearsAtThisCompany, ExperienceYearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []
#
# [0 rows x 28 columns]

# %%
len(data.loc[data['ExperienceYearsAtThisCompany'] > upper_lim])
# Out:
# 56

# %%
data.loc[data['ExperienceYearsAtThisCompany']> upper_lim, 'ExperienceYearsAtThisCompany']= np.median(data['ExperienceYearsAtThisCompany'])

# %%
data.loc[data['ExperienceYearsAtThisCompany'] > upper_lim]
# Out:
# Empty DataFrame
# Columns: [EmpNumber, Age, Gender, EducationBackground, MaritalStatus, EmpDepartment, EmpJobRole, BusinessTravelFrequency, DistanceFromHome, EmpEducationLevel, EmpEnvironmentSatisfaction, EmpHourlyRate, EmpJobInvolvement, EmpJobLevel, EmpJobSatisfaction, NumCompaniesWorked, OverTime, EmpLastSalaryHikePercent, EmpRelationshipSatisfaction, TotalWorkExperienceInYears, TrainingTimesLastYear, EmpWorkLifeBalance, ExperienceYearsAtThisCompany, ExperienceYearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Attrition, PerformanceRating]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# #### **ENCODING**

# %%
for column in data.drop('Attrition', axis=1):
    if data[column].dtype =='object':
        print(column)
        print("==============================")
# Out:
# EmpNumber
# ...
# Gender
# ...
# EducationBackground
# ...
# MaritalStatus
# ...
# EmpDepartment
# ...
# EmpJobRole
# ...
# BusinessTravelFrequency
# ...
# OverTime
# ...

# %%
binary_features
# Out:
# ['OverTime']

# %%
nominal_features
# Out:
# ['Gender',
#  'EducationBackground',
#  'MaritalStatus',
#  'EmpDepartment',
#  'EmpJobRole',
#  'BusinessTravelFrequency']

# %% [markdown]
# #### ***OverTime***

# %%
# binary features
# OverTime
data.OverTime.value_counts()
# Out:
# OverTime
# No     847
# Yes    353
# Name: count, dtype: int64

# %%
# yes=1, No= 0
# mapping is done
data['OverTime']= data['OverTime'].map({"No": 0, "Yes": 1})

# %%
data['OverTime'].head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: OverTime, dtype: int64

# %% [markdown]
# #### ***Gender***

# %%
# nominal features--> one-hot encoding is done
# Gender
data.Gender.value_counts()
# Out:
# Gender
# Male      725
# Female    475
# Name: count, dtype: int64

# %%
data['Gender']= pd.get_dummies(data['Gender'], drop_first=True)

# %%
data[['Gender']].tail()
# Out:
#       Gender
# 1195   False
# 1196    True
# 1197    True
# 1198   False
# 1199   False

# %% [markdown]
# #### ***EducationBackground***

# %%
# EducationBackground
data.EducationBackground.value_counts()
# Out:
# EducationBackground
# Life Sciences       492
# Medical             384
# Marketing           137
# Technical Degree    100
# Other                66
# Human Resources      21
# Name: count, dtype: int64

# %%
EducationBackground= pd.get_dummies(data['EducationBackground'], drop_first= True)

# %%
data= pd.concat([data, EducationBackground], axis=1)

# %%
data.drop('EducationBackground', axis=1, inplace= True)
data.head()
# Out:
#   EmpNumber  Age  Gender MaritalStatus    EmpDepartment       EmpJobRole  \
# 0  E1001000   32    True        Single            Sales  Sales Executive
# 1  E1001006   47    True        Single            Sales  Sales Executive
# 2  E1001007   40    True       Married            Sales  Sales Executive
# 3  E1001009   41    True      Divorced  Human Resources          Manager
# 4  E1001010   60    True        Single            Sales  Sales Executive
#
#   BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0           Travel_Rarely                10                  3
# 1           Travel_Rarely                14                  4
# 2       Travel_Frequently                 5                  4
# 3           Travel_Rarely                10                  4
# 4           Travel_Rarely                16                  4
#
#    EmpEnvironmentSatisfaction  ...  ExperienceYearsInCurrentRole  \
# 0                           4  ...                             7
# ...

# %% [markdown]
# #### ***MaritalStatus***

# %%
# MaritalStatus
data.MaritalStatus.value_counts()
# Out:
# MaritalStatus
# Married     548
# Single      384
# Divorced    268
# Name: count, dtype: int64

# %%
# one hot encoding
MaritalStatus= pd.get_dummies(data['MaritalStatus'], drop_first= True)
data= pd.concat([data, MaritalStatus], axis= 1)

# %%
data.drop('MaritalStatus', axis=1, inplace= True)
data.head()
# Out:
#   EmpNumber  Age  Gender    EmpDepartment       EmpJobRole  \
# 0  E1001000   32    True            Sales  Sales Executive
# 1  E1001006   47    True            Sales  Sales Executive
# 2  E1001007   40    True            Sales  Sales Executive
# 3  E1001009   41    True  Human Resources          Manager
# 4  E1001010   60    True            Sales  Sales Executive
#
#   BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0           Travel_Rarely                10                  3
# 1           Travel_Rarely                14                  4
# 2       Travel_Frequently                 5                  4
# 3           Travel_Rarely                10                  4
# 4           Travel_Rarely                16                  4
#
#    EmpEnvironmentSatisfaction  EmpHourlyRate  ...  YearsWithCurrManager  \
# 0                           4             55  ...                     8
# 1                           4             42  ...                     7
# ...

# %% [markdown]
# #### ***EmpDepartment***

# %%
data.EmpDepartment.value_counts()
# Out:
# EmpDepartment
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: count, dtype: int64

# %%
EmpDepartment= pd.get_dummies(data['EmpDepartment'], drop_first= True)
data= pd.concat([data, EmpDepartment], axis=1)

# %%
data.drop('EmpDepartment', axis=1, inplace= True)
data
# Out:
#      EmpNumber  Age  Gender        EmpJobRole BusinessTravelFrequency  \
# 0     E1001000   32    True   Sales Executive           Travel_Rarely
# 1     E1001006   47    True   Sales Executive           Travel_Rarely
# 2     E1001007   40    True   Sales Executive       Travel_Frequently
# 3     E1001009   41    True           Manager           Travel_Rarely
# 4     E1001010   60    True   Sales Executive           Travel_Rarely
# ...        ...  ...     ...               ...                     ...
# 1195   E100992   27   False   Sales Executive       Travel_Frequently
# 1196   E100993   37    True  Senior Developer           Travel_Rarely
# 1197   E100994   50    True  Senior Developer           Travel_Rarely
# 1198   E100995   34   False    Data Scientist           Travel_Rarely
# 1199   E100998   24   False   Sales Executive           Travel_Rarely
#
#       DistanceFromHome  EmpEducationLevel  EmpEnvironmentSatisfaction  \
# ...

# %% [markdown]
# #### ***EmpJobRole***

# %%
data.EmpJobRole.value_counts()
# Out:
# EmpJobRole
# Sales Executive              270
# Developer                    236
# Manager R&D                   94
# Research Scientist            77
# Sales Representative          69
# Laboratory Technician         64
# Senior Developer              52
# Manager                       51
# Finance Manager               49
# Human Resources               45
# Technical Lead                38
# Manufacturing Director        33
# Healthcare Representative     33
# Data Scientist                20
# Research Director             19
# Business Analyst              16
# Senior Manager R&D            15
# Delivery Manager              12
# Technical Architect            7
# Name: count, dtype: int64

# %%
EmpJobRole= pd.get_dummies(data['EmpJobRole'], drop_first= True)
data= pd.concat([data, EmpJobRole], axis=1)

# %%
data.drop('EmpJobRole', axis=1, inplace= True)
data.head()
# Out:
#   EmpNumber  Age  Gender BusinessTravelFrequency  DistanceFromHome  \
# 0  E1001000   32    True           Travel_Rarely                10
# 1  E1001006   47    True           Travel_Rarely                14
# 2  E1001007   40    True       Travel_Frequently                 5
# 3  E1001009   41    True           Travel_Rarely                10
# 4  E1001010   60    True           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           4             55
# 1                  4                           4             42
# 2                  4                           4             48
# 3                  4                           2             73
# 4                  4                           1             84
#
#    EmpJobInvolvement  EmpJobLevel  ...  Manager R&D  Manufacturing Director  \
# 0                  3            2  ...        False                   False
# ...

# %% [markdown]
# #### ***BusinessTravelFrequency***

# %%
data.BusinessTravelFrequency.value_counts()
# Out:
# BusinessTravelFrequency
# Travel_Rarely        846
# Travel_Frequently    222
# Non-Travel           132
# Name: count, dtype: int64

# %%
BusinessTravelFrequency= pd.get_dummies(data['BusinessTravelFrequency'], drop_first= True)
data= pd.concat([data, BusinessTravelFrequency], axis=1)

# %%
data.drop('BusinessTravelFrequency', axis=1, inplace= True)
data.head()
# Out:
#   EmpNumber  Age  Gender  DistanceFromHome  EmpEducationLevel  \
# 0  E1001000   32    True                10                  3
# 1  E1001006   47    True                14                  4
# 2  E1001007   40    True                 5                  4
# 3  E1001009   41    True                10                  4
# 4  E1001010   60    True                16                  4
#
#    EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  \
# 0                           4             55                  3            2
# 1                           4             42                  3            2
# 2                           4             48                  2            3
# 3                           2             73                  2            5
# 4                           1             84                  3            2
#
#    EmpJobSatisfaction  ...  Research Director  Research Scientist  \
# ...

# %% [markdown]
# #### ***Attrition***

# %%
data.Attrition.value_counts()
# Out:
# Attrition
# No     1022
# Yes     178
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lb= LabelEncoder()
data['Attrition']= lb.fit_transform(data["Attrition"])

# %%
data.Attrition.value_counts()
# Out:
# Attrition
# 0    1022
# 1     178
# Name: count, dtype: int64

# %%
data.dtypes
# Out:
# EmpNumber                       object
# Age                              int64
# Gender                            bool
# DistanceFromHome                 int64
# EmpEducationLevel                int64
# EmpEnvironmentSatisfaction       int64
# EmpHourlyRate                    int64
# EmpJobInvolvement                int64
# EmpJobLevel                      int64
# EmpJobSatisfaction               int64
# NumCompaniesWorked               int64
# OverTime                         int64
# EmpLastSalaryHikePercent         int64
# EmpRelationshipSatisfaction      int64
# TotalWorkExperienceInYears       int64
# TrainingTimesLastYear            int64
# EmpWorkLifeBalance               int64
# ExperienceYearsAtThisCompany     int64
# ExperienceYearsInCurrentRole     int64
# YearsSinceLastPromotion          int64
# YearsWithCurrManager             int64
# Attrition                        int32
# PerformanceRating                int64
# Life Sciences                     bool
# ...

# %%
# EmpNumber is ignored since it is a unique feature.
data.drop('EmpNumber', axis=1, inplace= True)
data.columns
# Out:
# Index(['Age', 'Gender', 'DistanceFromHome', 'EmpEducationLevel',
#        'EmpEnvironmentSatisfaction', 'EmpHourlyRate', 'EmpJobInvolvement',
#        'EmpJobLevel', 'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating',
#        'Life Sciences', 'Marketing', 'Medical', 'Other', 'Technical Degree',
#        'Married', 'Single', 'Development', 'Finance', 'Human Resources',
#        'Research & Development', 'Sales', 'Data Scientist', 'Delivery Manager',
#        'Developer', 'Finance Manager', 'Healthcare Representative',
#        'Human Resources', 'Laboratory Technician', 'Manager', 'Manager R&D',
# ...

# %% [markdown]
# #### **SCALING**

# %%
# continuous_columns
continuous_col
# Out:
# ['Age',
#  'DistanceFromHome',
#  'EmpHourlyRate',
#  'TotalWorkExperienceInYears',
#  'ExperienceYearsAtThisCompany']

# %%
# using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaling= MinMaxScaler()
data[['Age','DistanceFromHome', 'EmpHourlyRate', 'TotalWorkExperienceInYears', 'ExperienceYearsAtThisCompany']]= scaling.fit_transform(data[['Age', 'DistanceFromHome', 'EmpHourlyRate', 'TotalWorkExperienceInYears', 'ExperienceYearsAtThisCompany']])

# %%
data.head()
# Out:
#         Age  Gender  DistanceFromHome  EmpEducationLevel  \
# 0  0.333333    True          0.321429                  3
# 1  0.690476    True          0.464286                  4
# 2  0.523810    True          0.142857                  4
# 3  0.547619    True          0.321429                  4
# 4  1.000000    True          0.535714                  4
#
#    EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  \
# 0                           4       0.357143                  3            2
# 1                           4       0.171429                  3            2
# 2                           4       0.257143                  2            3
# 3                           2       0.614286                  2            5
# 4                           1       0.771429                  3            2
#
#    EmpJobSatisfaction  NumCompaniesWorked  ...  Research Director  \
# 0                   4                   1  ...              False
# ...

# %% [markdown]
# #### **BALANCING THE DATASET**

# %%
# splitting X and y
X= data.drop('Attrition', axis=1)
y= data['Attrition']

# %%
# train-test-split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X, y, stratify=y, test_size=0.2, random_state= 42)

# %%
# importing SMOTE
from imblearn.over_sampling import SMOTE
smote= SMOTE()
X_train_sm, y_train_sm= smote.fit_resample(X_train, y_train)

# %%
from collections import Counter
print(Counter(y_train))
print(Counter(y_train_sm))
# Out:
# Counter({0: 818, 1: 142})
# Counter({0: 818, 1: 818})

# %% [markdown]
# ### **FEATURE SELECTION**

# %%
# Statistical measurement of relationship between the variables

# %%
plt.figure(figsize= (15, 15), dpi= 100)
heatmap= sns.heatmap(data.corr()[['Attrition']].sort_values(by= 'Attrition', ascending= False),
                     vmin= -1, vmax = 1, annot= True, cmap= 'twilight')

# Looping through the text elements and setting the font weight to bold
for text in heatmap.texts:
    text.set_fontweight('bold')

heatmap.set_title('Correlation of features with "Exited"', fontsize= 12, pad= 18, fontweight= 'bold')
plt.show()

# %% [markdown]
# ##### Insights:
# - Most of the features show correlation close to 0 but dropping all of them might lead to loss of information.
# - Hence no column is dropped here.

# %% [markdown]
# ### **MODEL BUILDING**:

# %% [markdown]
# #### **LOGISTIC REGRESSION**

# %%
# Splitting features and target variable

X= data.drop('Attrition', axis= 1)
y= data[['Attrition']]

# %%
#Checking the shape of X and y

print(f'X: {X.shape}\ny: {y.shape}')
# Out:
# X: (1200, 53)
# y: (1200, 1)

# %%
# finding the best test size

# Array of test size values from 0.2 to 0.3
test_size= np.arange(start=0.2, stop= 0.35, step= 0.05)

#importing the required libraries for the model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

#Initialising a list to store the score of each test size
score= []

for size in test_size:
  X_train1, X_test1, y_train1, y_test1= train_test_split(X, y, stratify=y, test_size= size, random_state=0)
  lg_reg= LogisticRegression()
  lg_reg.fit(X_train1, y_train1)
  score.append(lg_reg.score(X_test1, y_test1))

# Creating a dataframe to display the results
l= pd.DataFrame({'Test size': test_size, 'Score': score })
l.sort_values(by=['Score'], ascending = False, inplace = True)
l.style.highlight_max(color='cornflowerblue')
# Out:
# <style type="text/css">
# #T_2a98a_row0_col1, #T_2a98a_row1_col0, #T_2a98a_row1_col1 {
#   background-color: cornflowerblue;
# }
# </style>
# <table id="T_2a98a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a98a_level0_col0" class="col_heading level0 col0" >Test size</th>
#       <th id="T_2a98a_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a98a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a98a_row0_col0" class="data row0 col0" >0.200000</td>
#       <td id="T_2a98a_row0_col1" class="data row0 col1" >0.891667</td>
#     </tr>
#     <tr>
#       <th id="T_2a98a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2a98a_row1_col0" class="data row1 col0" >0.300000</td>
#       <td id="T_2a98a_row1_col1" class="data row1 col1" >0.891667</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Hence the test size of all three options turned out to be the better ones for **Logistic Regression model**

# %% [markdown]
# #### ***Train Test Split***

# %%
# Splitting x and y into training and testing sets
X_train1, X_test1, y_train1, y_test1= train_test_split(X, y, stratify=y, test_size= 0.3, random_state=0)

# %%
# Checking the shape
print(f'X_train shape: {X_train1.shape}\nX_test shape: {X_test1.shape}')
print(f'y_train shape: {y_train1.shape}\ny_test shape: {y_test1.shape}')
# Out:
# X_train shape: (840, 53)
# X_test shape: (360, 53)
# y_train shape: (840, 1)
# y_test shape: (360, 1)

# %% [markdown]
# #### ***Training the Logistic Regression model***

# %%
# Initializing the model
lg_model= LogisticRegression()

# fitting the model to the train data
lg_model.fit(X_train1, y_train1)
# Out:
# LogisticRegression()

# %% [markdown]
# #### ***Prediction***

# %%
y_pred= lg_model.predict(X_test1)

# %% [markdown]
# #### ***Model Evaluation:***

# %%
# Checking Accuracy score

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
a= accuracy_score(y_test1, y_pred)
print(f'Model accuracy score: {a}')
# Out:
# Model accuracy score: 0.8916666666666667

# %%
print(f'Precision score: {precision_score(y_test1, y_pred)}\
        \nRecall score: {recall_score(y_test1, y_pred)}\
        \nf1 score: {f1_score(y_test1, y_pred)}')
# Out:
# Precision score: 0.7692307692307693
# Recall score: 0.37735849056603776
# f1 score: 0.5063291139240507

# %%
# Checking for overfitting and underfitting

Training_accuracy= lg_model.score(X_train1, y_train1)
Testing_accuracy= lg_model.score(X_test1, y_test1)
print(f'Training set score: {Training_accuracy}')
print(f'Testing set score: {Testing_accuracy}')
# Out:
# Training set score: 0.9035714285714286
# Testing set score: 0.8916666666666667

# %% [markdown]
# The **training set accuracy** is **0.90** whereas the **testing set accuracy** is **0.89**. Hence the model is not that much overfitted.

# %%
# K-Fold Cross-validation

from sklearn.model_selection import KFold, cross_val_score, cross_val_predict
kf= KFold(n_splits= 10, shuffle= False)

# %%
# cross validation accuracy

score= cross_val_score(lg_model, X, y, cv= kf, scoring= 'accuracy')
print(f'Cross validation accuracy scores: {score}')
# Out:
# Cross validation accuracy scores: [0.84166667 0.85833333 0.90833333 0.86666667 0.925      0.925
#  0.91666667 0.90833333 0.875      0.9       ]

# %%
LG_acc= pd.DataFrame({'CV mean': score.mean(), 'Std': score.std()}, index= ['Cross validation accuracy'])
LG_acc
# Out:
#                            CV mean       Std
# Cross validation accuracy   0.8925  0.028247

# %% [markdown]
# - The **mean cross validation** of the model is 0.89 which shows that the model is expected to be around **89%** accurate on average.
# - **10 fold cross validation** accuracy does not show any significant improvement in the model's performance.

# %%
# Confusion matrix

from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(lg_model, X_test1, y_test1, colorbar= False, cmap= 'Blues')
plt.title('Confusion matrix of Base Decision Tree')
plt.grid(False)

# %%
# classification report

print(classification_report(y_test1, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       307
#            1       0.77      0.38      0.51        53
#
#     accuracy                           0.89       360
#    macro avg       0.84      0.68      0.72       360
# weighted avg       0.88      0.89      0.88       360

# %%
# Performance metrics

'''Defining a function to calculate all the required performance metrics
for the given model'''
def metrics_calculator(y_test, y_pred, model_name):


  result= pd.DataFrame(data= [accuracy_score(y_test, y_pred),
                              precision_score(y_test, y_pred),
                              recall_score(y_test, y_pred),
                              f1_score(y_test, y_pred)],
                       index=['Accuracy','precision','Recall', 'F1-score'],
                       columns= [model_name])
  return result

# %%
Base_lg_result= metrics_calculator(y_test1, y_pred, 'Base Logistic Regression')
Base_lg_result
# Out:
#            Base Logistic Regression
# Accuracy                   0.891667
# precision                  0.769231
# Recall                     0.377358
# F1-score                   0.506329

# %%
# saving it in a different dataframe for model conclusion report

Base_lg_result1= pd.DataFrame(data= [0.891667, 0.769231, 0.377358, 0.506329], 
                              index= ['Accuracy','precision','Recall', 'F1-score'],
                              columns= ['Base Decision Tree'])
Base_lg_result1.style.background_gradient(cmap= 'Blues')
# Out:
# <style type="text/css">
# #T_a0fb1_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a0fb1_row1_col0 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_a0fb1_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a0fb1_row3_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# </style>
# <table id="T_a0fb1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0fb1_level0_col0" class="col_heading level0 col0" >Base Decision Tree</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0fb1_level0_row0" class="row_heading level0 row0" >Accuracy</th>
#       <td id="T_a0fb1_row0_col0" class="data row0 col0" >0.891667</td>
#     </tr>
#     <tr>
#       <th id="T_a0fb1_level0_row1" class="row_heading level0 row1" >precision</th>
#       <td id="T_a0fb1_row1_col0" class="data row1 col0" >0.769231</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# #### **TUNING LOGISTIC REGRESSION HYPERPARAMETERS USING GRID SEARCH CV**

# %% [markdown]
# #### ***Finding optimal hyper parameters(GridSearchCV)***

# %%
# Defining model
model = LogisticRegression()

# Defining evaluation
from sklearn.model_selection import RepeatedStratifiedKFold
cv= RepeatedStratifiedKFold(n_splits=10, n_repeats= 3, random_state= 0)

# Defining search parameters
penalty = ['l1', 'l2', 'elasticnet', 'none']
C = [0.001, 0.01, 0.1, 1, 10, 100]
solver = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
max_iter = [100, 200, 300, 400, 500]

param_grid= {'penalty': penalty, 'C': C, 'solver': solver, 'max_iter': max_iter}

# Defining search
from sklearn.model_selection import GridSearchCV
search= GridSearchCV(model, param_grid, scoring= 'accuracy', n_jobs= -1, cv= cv)

# Executing search
GridSearchCV = search.fit(X_train1, y_train1)

# Setting the classifier to the best combination of parameters
tuned_lg_model_cv= GridSearchCV.best_estimator_

# Summarizing the result
print('Best Score: ', GridSearchCV.best_score_)
print('Best hyperparameters: ', GridSearchCV.best_params_)
# Out:
# Best Score:  0.8908730158730159
# Best hyperparameters:  {'C': 1, 'max_iter': 200, 'penalty': 'l2', 'solver': 'lbfgs'}

# %% [markdown]
# #### ***Tuned Logistic Regression Model***

# %%
# Training the tuned model

tuned_lg_model_cv.fit(X_train1, y_train1)
# Out:
# LogisticRegression(C=1, max_iter=200)

# %%
# prediction

y_pred= tuned_lg_model_cv.predict(X_test1)

# %%
# Tuned model evaluation

# Accuracy score

print(f'Tuned DT model accuracy score:\n {accuracy_score(y_test1, y_pred)}')
# Out:
# Tuned DT model accuracy score:
#  0.8888888888888888

# %%
print(f'Precision score: {precision_score(y_test1, y_pred)}\
        \nRecall score: {recall_score(y_test1, y_pred)}\
        \nf1 score: {f1_score(y_test1, y_pred)}')
# Out:
# Precision score: 0.76
# Recall score: 0.3584905660377358
# f1 score: 0.48717948717948717

# %%
# Checking for overfitting and underfitting

Training_accuracy= tuned_lg_model_cv.score(X_train1, y_train1)
Testing_accuracy= tuned_lg_model_cv.score(X_test1, y_test1)
print(f'Training set score: {Training_accuracy}')
print(f'Testing set score: {Testing_accuracy}')
# Out:
# Training set score: 0.9071428571428571
# Testing set score: 0.8888888888888888

# %% [markdown]
# #### Insights:
# - After tuning also, the training score is not reduced and is worse than the base logistic regression model.

# %%
# Tuned model confusion matrix

ConfusionMatrixDisplay.from_estimator(tuned_lg_model_cv, X_test1, y_test1, colorbar= False, cmap= 'Blues')
plt.title('Confusion matrix of Tuned Decision Tree')
plt.grid(False)

# %%
# tuned model classification report

print(classification_report(y_test1, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94       307
#            1       0.76      0.36      0.49        53
#
#     accuracy                           0.89       360
#    macro avg       0.83      0.67      0.71       360
# weighted avg       0.88      0.89      0.87       360

# %%
# tuned model performance metrics

tuned_lg_result= metrics_calculator(y_test1, y_pred, 'Tuned Logistic Regression')
tuned_lg_result
# Out:
#            Tuned Logistic Regression
# Accuracy                    0.888889
# precision                   0.760000
# Recall                      0.358491
# F1-score                    0.487179

# %%
# saving it in a different dataframe for model conclusion report
tuned_dt_result1= pd.DataFrame(data= [0.888889, 0.760000, 0.358491, 0.487179],                            
                              index= ['Accuracy','precision','Recall', 'F1-score'],
                              columns= ['Tuned Logistic Regression'])
tuned_dt_result1.style.background_gradient(cmap= 'Blues')
# Out:
# <style type="text/css">
# #T_e3979_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e3979_row1_col0 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_e3979_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e3979_row3_col0 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# </style>
# <table id="T_e3979">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3979_level0_col0" class="col_heading level0 col0" >Tuned Logistic Regression</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3979_level0_row0" class="row_heading level0 row0" >Accuracy</th>
#       <td id="T_e3979_row0_col0" class="data row0 col0" >0.888889</td>
#     </tr>
#     <tr>
#       <th id="T_e3979_level0_row1" class="row_heading level0 row1" >precision</th>
#       <td id="T_e3979_row1_col0" class="data row1 col0" >0.760000</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### **DECISION TREE:**

# %%
# Splitting features and target variable

X= data.drop('Attrition', axis= 1)
y= data[['Attrition']]

# %%
#Checking the shape of X and y

print(f'X: {X.shape}\ny: {y.shape}')
# Out:
# X: (1200, 53)
# y: (1200, 1)

# %%
# finding the best test size

# Array of test size values from 0.2 to 0.3
test_size= np.arange(start=0.2, stop= 0.35, step= 0.05)

#importing the required libraries for the model
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

#Initialising a list to store the score of each test size
score= []

for size in test_size:
  X_train2, X_test2, y_train2, y_test2= train_test_split(X, y, stratify = y, test_size= size, random_state=0)
  dt_clf= DecisionTreeClassifier()
  dt_clf.fit(X_train2, y_train2)
  score.append(dt_clf.score(X_test2, y_test2))

# Creating a dataframe to display the results
d= pd.DataFrame({'Test size': test_size, 'Score': score })
d.sort_values(by=['Score'], ascending = False, inplace = True)
d.style.highlight_max(color='limegreen')
# Out:
# <style type="text/css">
# #T_0dfd5_row0_col1, #T_0dfd5_row2_col0 {
#   background-color: limegreen;
# }
# </style>
# <table id="T_0dfd5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0dfd5_level0_col0" class="col_heading level0 col0" >Test size</th>
#       <th id="T_0dfd5_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0dfd5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0dfd5_row0_col0" class="data row0 col0" >0.200000</td>
#       <td id="T_0dfd5_row0_col1" class="data row0 col1" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_0dfd5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0dfd5_row1_col0" class="data row1 col0" >0.250000</td>
#       <td id="T_0dfd5_row1_col1" class="data row1 col1" >0.796667</td>
#     </tr>
#     <tr>
#       <th id="T_0dfd5_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# Hence the test size of **0.2** is the better one for **Decision Tree modeling**.

# %% [markdown]
# #### ***Train Test Split***

# %%
# Splitting x and y into training and testing sets
X_train2, X_test2, y_train2, y_test2= train_test_split(X, y, stratify=y, test_size= 0.2, random_state=0)

# %%
# Checking the shape
print(f'X_train shape: {X_train2.shape}\nX_test shape: {X_test2.shape}')
print(f'y_train shape: {y_train2.shape}\ny_test shape: {y_test2.shape}')
# Out:
# X_train shape: (960, 53)
# X_test shape: (240, 53)
# y_train shape: (960, 1)
# y_test shape: (240, 1)

# %% [markdown]
# #### ***Training the Decision tree model***

# %%
# Initializing the model
dt_model= DecisionTreeClassifier()

# fitting the model to the train data
dt_model.fit(X_train2, y_train2)
# Out:
# DecisionTreeClassifier()

# %%
# prediction
y_pred= dt_model.predict(X_test2)

# %%
# Model evaluation

# Checking Accuracy score

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
a= accuracy_score(y_test2, y_pred)
print(f'Model accuracy score: {a}')
# Out:
# Model accuracy score: 0.8291666666666667

# %%
print(f'Precision score: {precision_score(y_test2, y_pred)}\
        \nRecall score: {recall_score(y_test2, y_pred)}\
        \nf1 score: {f1_score(y_test2, y_pred)}')
# Out:
# Precision score: 0.43243243243243246
# Recall score: 0.4444444444444444
# f1 score: 0.4383561643835616

# %%
# Checking for overfitting and underfitting

Training_accuracy= dt_model.score(X_train2, y_train2)
Testing_accuracy= dt_model.score(X_test2, y_test2)
print(f'Training set score: {Training_accuracy}')
print(f'Testing set score: {Testing_accuracy}')
# Out:
# Training set score: 1.0
# Testing set score: 0.8291666666666667

# %% [markdown]
# The **training set accuracy** is **1.0** whereas the **testing set accuracy** is **0.82**. Clearly the model is overfitted.

# %%
# K-Fold Cross-validation

from sklearn.model_selection import KFold, cross_val_score, cross_val_predict
kf= KFold(n_splits= 10, shuffle= False)

# %%
# cross validation accuracy

score= cross_val_score(dt_model, X, y, cv= kf, scoring= 'accuracy')
print(f'Cross validation accuracy scores: {score}')
# Out:
# Cross validation accuracy scores: [0.78333333 0.83333333 0.76666667 0.85833333 0.85833333 0.825
#  0.79166667 0.775      0.825      0.83333333]

# %%
DT_acc= pd.DataFrame({'CV mean': score.mean(), 'Std': score.std()}, index= ['Cross validation accuracy'])
DT_acc
# Out:
#                            CV mean       Std
# Cross validation accuracy    0.815  0.031798

# %% [markdown]
# - The **mean cross validation** of the model is 0.81 which shows that the model is expected to be around **81%** accurate on average.
# - **10 fold cross validation** accuracy does not show any significant improvement in the model's performance.

# %%
# Confusion matrix

from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(dt_model, X_test2, y_test2, colorbar= False, cmap= 'YlGn')
plt.title('Confusion matrix of Base Decision Tree')
plt.grid(False)

# %%
# classification report

print(classification_report(y_test2, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       204
#            1       0.43      0.44      0.44        36
#
#     accuracy                           0.83       240
#    macro avg       0.67      0.67      0.67       240
# weighted avg       0.83      0.83      0.83       240

# %%
# Performance metrics

'''Defining a function to calculate all the required performance metrics
for the given model'''
def metrics_calculator(y_test, y_pred, model_name):


  result= pd.DataFrame(data= [accuracy_score(y_test, y_pred),
                              precision_score(y_test, y_pred),
                              recall_score(y_test, y_pred),
                              f1_score(y_test, y_pred)],
                       index=['Accuracy','precision','Recall', 'F1-score'],
                       columns= [model_name])
  return result

# %%
Base_dt_result= metrics_calculator(y_test2, y_pred, 'Base Decision Tree')
Base_dt_result
# Out:
#            Base Decision Tree
# Accuracy             0.829167
# precision            0.432432
# Recall               0.444444
# F1-score             0.438356

# %%
# saving it in a different dataframe for model conclusion report

Base_dt_result1= pd.DataFrame(data= [0.829167, 0.432432, 0.444444, 0.438356], 
                              index= ['Accuracy','precision','Recall', 'F1-score'],
                              columns= ['Base Decision Tree'])
Base_dt_result1.style.background_gradient(cmap= 'YlGn')
# Out:
# <style type="text/css">
# #T_5a8a7_row0_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_5a8a7_row1_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_5a8a7_row2_col0 {
#   background-color: #fdfedb;
#   color: #000000;
# }
# #T_5a8a7_row3_col0 {
#   background-color: #feffe1;
#   color: #000000;
# }
# </style>
# <table id="T_5a8a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a8a7_level0_col0" class="col_heading level0 col0" >Base Decision Tree</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a8a7_level0_row0" class="row_heading level0 row0" >Accuracy</th>
#       <td id="T_5a8a7_row0_col0" class="data row0 col0" >0.829167</td>
#     </tr>
#     <tr>
#       <th id="T_5a8a7_level0_row1" class="row_heading level0 row1" >precision</th>
#       <td id="T_5a8a7_row1_col0" class="data row1 col0" >0.432432</td>
#     </tr>
#     <tr>
# ...

# %%
# feature importance

# getting feature importances from the decision tree model
importances= dt_model.feature_importances_
feature_names= X.columns

# sorting the features by importance
indices= np.argsort(importances)

# Creating a horizontal bar plot of the feature importances
plt.figure(figsize= (15, 15))
plt.barh(range(len(indices)), importances[indices], color= 'limegreen', align= 'center')
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel('Relative Importance')

# Adding labels to the bars
for i, v in enumerate(importances[indices]):
  plt.text(v, i, str(round(v, 3)), color= 'black', fontsize= 7)

plt.show()

# %% [markdown]
# #### **TUNING DECISION TREE HYPERPARAMETERS USING GRID SEARCH CV**

# %% [markdown]
# #### ***Finding optimal hyper parameters(GridSearchCV)***

# %%
# Defining model
model = DecisionTreeClassifier()

# Defining evaluation
from sklearn.model_selection import RepeatedStratifiedKFold
cv= RepeatedStratifiedKFold(n_splits=10, n_repeats= 3, random_state= 0)

# Defining search parameters
max_depth= range(2, 20)
criterion= ['entropy', 'gini']
min_samples_split= [2, 3, 4]
min_samples_leaf= [1, 2, 3]

param_grid= {'max_depth': max_depth, 'criterion': criterion, 'min_samples_split': min_samples_split,
             'min_samples_leaf': min_samples_leaf}

# Defining search
from sklearn.model_selection import GridSearchCV
search= GridSearchCV(model, param_grid, scoring= 'accuracy', n_jobs= -1, cv= cv)

# Executing search
GridSearchCV = search.fit(X_train2, y_train2)

# Setting the classifier to the best combination of parameters
tuned_dt_model_cv= GridSearchCV.best_estimator_

# Summarizing the result
print('Best Score: ', GridSearchCV.best_score_)
print('Best hyperparameters: ', GridSearchCV.best_params_)
# Out:
# Best Score:  0.8552083333333333
# Best hyperparameters:  {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %% [markdown]
# #### ***Tuned Decision Tree Model***

# %%
# Training the tuned model

tuned_dt_model_cv.fit(X_train2, y_train2)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
# prediction

y_pred= tuned_dt_model_cv.predict(X_test2)

# %%
# Tuned model evaluation
# Accuracy score

print(f'Tuned DT model accuracy score:\n {accuracy_score(y_test2, y_pred)}')
# Out:
# Tuned DT model accuracy score:
#  0.8541666666666666

# %%
print(f'Precision score: {precision_score(y_test2, y_pred)}\
        \nRecall score: {recall_score(y_test2, y_pred)}\
        \nf1 score: {f1_score(y_test2, y_pred)}')
# Out:
# Precision score: 0.5217391304347826
# Recall score: 0.3333333333333333
# f1 score: 0.4067796610169491

# %%
# Checking for overfitting and underfitting

Training_accuracy= tuned_dt_model_cv.score(X_train2, y_train2)
Testing_accuracy= tuned_dt_model_cv.score(X_test2, y_test2)
print(f'Training set score: {Training_accuracy}')
print(f'Testing set score: {Testing_accuracy}')
# Out:
# Training set score: 0.8947916666666667
# Testing set score: 0.8541666666666666

# %% [markdown]
# #### Insights:
# - After tuning, the training score is drastically reduced and significantly closer to testing score.

# %%
# Tuned model confusion matrix

ConfusionMatrixDisplay.from_estimator(tuned_dt_model_cv, X_test2, y_test2, colorbar= False, cmap= 'YlGn')
plt.title('Confusion matrix of Tuned Decision Tree')
plt.grid(False)

# %%
# tuned model classification report

print(classification_report(y_test2, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       204
#            1       0.52      0.33      0.41        36
#
#     accuracy                           0.85       240
#    macro avg       0.71      0.64      0.66       240
# weighted avg       0.83      0.85      0.84       240

# %%
# tuned model performance metrics

tuned_dt_result= metrics_calculator(y_test2, y_pred, 'Tuned Decision Tree')
tuned_dt_result
# Out:
#            Tuned Decision Tree
# Accuracy              0.854167
# precision             0.521739
# Recall                0.333333
# F1-score              0.406780

# %%
# saving it in a different dataframe for model conclusion report
tuned_dt_result1= pd.DataFrame(data= [0.854167, 0.521739, 0.333333, 0.406780],                            
                              index= ['Accuracy','precision','Recall', 'F1-score'],
                              columns= ['Tuned Decision Tree'])
tuned_dt_result1.style.background_gradient(cmap= 'YlGn')
# Out:
# <style type="text/css">
# #T_f9763_row0_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_f9763_row1_col0 {
#   background-color: #b2df90;
#   color: #000000;
# }
# #T_f9763_row2_col0 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_f9763_row3_col0 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# </style>
# <table id="T_f9763">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9763_level0_col0" class="col_heading level0 col0" >Tuned Decision Tree</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9763_level0_row0" class="row_heading level0 row0" >Accuracy</th>
#       <td id="T_f9763_row0_col0" class="data row0 col0" >0.854167</td>
#     </tr>
#     <tr>
#       <th id="T_f9763_level0_row1" class="row_heading level0 row1" >precision</th>
#       <td id="T_f9763_row1_col0" class="data row1 col0" >0.521739</td>
#     </tr>
#     <tr>
# ...

# %%
# tuned model feature importance

#getting feature importances from the tuned decision tree model
importances= tuned_dt_model_cv.feature_importances_
feature_names= X.columns

# sort the features by importance
indices= np.argsort(importances)

# Creating a horizontal bar plot of the feature importances
plt.figure(figsize= (15, 15))
plt.barh(range(len(indices)), importances[indices], color= 'limegreen', align= 'center')
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel('Relative Importance')

# Adding labels to the bars
for i, v in enumerate(importances[indices]):
  plt.text(v, i, str(round(v, 3)), color= 'black', fontsize= 7)

plt.show()

# %% [markdown]
# ### **RANDOM FOREST:**
